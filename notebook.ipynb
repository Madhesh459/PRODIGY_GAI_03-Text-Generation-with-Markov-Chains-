# %% [markdown]
# # 🌟 Text Generation with Markov Chains
#
# This interactive notebook lets you run and test the Markov Chain Text Generator directly in your browser without installing anything locally.
#
# ### 🚀 How to Run:
# 1. Hover over the code cell below and click the **Play (Run)** button.
# 2. The system will download the repository, run the CLI, and prompt you for inputs inside the execution console.
# 3. Use the defaults by pressing **`Enter`** in the inputs, or customize the lookback order and word length.

# %%
# 1. Clone the project repository
# !git clone https://github.com/Madhesh459/PRODIGY_GAI_03-Text-Generation-with-Markov-Chains-.git

# 2. Change directory into the project root
# %cd PRODIGY_GAI_03-Text-Generation-with-Markov-Chains-

# 3. Execute the interactive program
# !python main.py
